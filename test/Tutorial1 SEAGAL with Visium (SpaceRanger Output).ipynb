# %%
from seagal import seagal

# %%
sg = seagal.SEAGAL(visium_path='data/VisiumData/Human_Breast_Cancer_BAS1')
# Out:
#   0%|          | 0/1 [00:00<?, ?/s]

# %%
seagal.group_adata_by_genes(sg, inplace=True)
# Out:
# B cells: 19 markers: IGKC,EBF1,BANK1,CD79A,IGHD,BACH2,IGHM,FCHSD2,LY6D,PAX5,RALGPS2,IGLC2,AFF3,BTLA,MEF2C,CD79B,MS4A1,FOXP1,CD55.
# Endothelial: 17 markers: LCN2,PHLDA1,KRT18,MAP1LC3A,HRAS,AQP5,KRT8,CRIP2,CDKN1A,DBI,PGP,RPS27L,SPINT2,MRPS6,DSTN,HMGN1,XBP1.
# ILC: 14 markers: CD7,GZMB,XCL1,IL2RB,NKG7,CTSW,CCL5,KLRD1,TMSB10,KLRK1,CST7,NCR1,LCK,SH2D2A.
# Macrophages: 20 markers: APOE,C1QA,C1QC,C1QB,MS4A7,CD81,CCL4,RGS1,CD72,CTSS,HEXB,CTSB,ACP5,CD63,LGMN,LY86,AIF1,GRN,PLD4,CXCL16.
# Monocytes: 14 markers: CRIP1,PLAC8,S100A4,F13A1,AHNAK,CCR2,IFITM3,VIM,ALOX5AP,PLTP,TAGLN2,PID1,ANXA2,EMP3.
# Neutrophils: 16 markers: S100A8,S100A9,CSF3R,IFITM1,SLPI,HDC,MMP9,CXCR2,PBX1,GSR,MXD1,SORL1,CLEC4D,S100A11,IL1R2,CD44.
# T cells: 18 markers: LEF1,SKAP1,CD3E,ITK,CD3G,CD3D,INPP4B,LAT,SATB1,PRKCQ,THY1,CD247,TRBC2,BCL11B,NKG7,GRAP2,TCF7,BCL2.
#   0%|          | 0/100 [00:00<?, ?/s]
# Calculating global graph-based correlation value...

# %%
seagal.clustermap(sg, figsize=(6,6), use_grouped=True)
## Save the spatial correlation matrix for grouped genes
seagal.save_coexpr(sg, path='results/spatial_ct_colocolize.csv', use_grouped=True)

# %%
f,_ = seagal.hotspot(sg, 'B cells', 'T cells', use_grouped=True, cmap='bwr')
f.savefig("results/B&T.pdf", dpi=100, bbox_inches='tight')
# Out:
# Calculating local spatial correlation value...
# Local L elapsed time: 0.186s

# %%
f,_ = seagal.hotspot(sg, 'Neutrophils', 'B cells', use_grouped=True, cmap='bwr')
f.savefig("results/Neutro&Bcells.pdf", dpi=100, bbox_inches='tight')
# Out:
# Calculating local spatial correlation value...
# Local L elapsed time: 0.168s

# %%
f = seagal.volcano(sg, use_grouped=True)

# %%
seagal.spatial_pattern_genes(sg, I=0.4, topK=None)
seagal.spatial_association(sg, grouped_only=False)
# Out:
# #Extracted genes with spatial patterns = 44
# #Genes to be used is 44. #Pairs = 946, Estimated elapsed time: 0.044 hours.
# Calculating global graph-based correlation value...

# %%
f = seagal.volcano(sg, use_grouped=False)

# %%
# Visualize a gene pairs local spatial correlation 
f, _ = seagal.hotspot(sg, "IGKC", 'IGHG4')
f.savefig("results/IGKC_IGHG4.pdf", dpi=100, bbox_inches='tight')
# Out:
# Calculating local spatial correlation value...
# Local L elapsed time: 0.990s

# %%
g = seagal.clustermap(sg, use_grouped=False, figsize=(6, 6))
## Save the spatial correlation matrix
seagal.save_coexpr(sg, path='results/spatial_coexpr.csv', use_grouped=False)

# %%
seagal.genemodules(sg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.315972175705335
# For n_clusters = 3 The average silhouette_score is : 0.4051299889563964
# For n_clusters = 4 The average silhouette_score is : 0.3536831110198858
# For n_clusters = 5 The average silhouette_score is : 0.2847632370942446
# For n_clusters = 6 The average silhouette_score is : 0.2557953484111223
# Number of selected clusters =  3

# %%
sg.module_dict['module_df'].iloc[:3,:]
# Out:
#        label  silhouette
# APOE      m1     0.40513
# ARPP21    m2     0.40513
# B2M       m1     0.40513

# %%
seagal.module_pattern(sg)
# Out:
# m1: 15 markers: APOE,B2M,CD74,FTL,HLA-A,HLA-B,HLA-DRA,IGHG1,IGHG3,IGHG4,IGKC,IGLC2,MALAT1,RPL36,TMSB10.
# m2: 12 markers: ARPP21,CRIP1,IGFBP5,KRT18,KRT8,MUC1,RPL13,RPL41,RPLP1,S100A11,SPAG6,Z82214.2.
# m0: 17 markers: COX6C,CPB1,IFI27,KRT19,LINC00645,MGP,MT-ATP6,MT-CO1,MT-CO2,MT-CO3,MT-CYB,MT-ND1,MT-ND2,MT-ND3,MT-ND4,S100A6,TFF3.
#   0%|          | 0/100 [00:00<?, ?/s]

# %%
seagal.module_hotspot(sg, cmap='bwr', vmax=4, vmin=-4)
# Out:
# m1: 15 markers: APOE,B2M,CD74,FTL,HLA-A,HLA-B,HLA-DRA,IGHG1,IGHG3,IGHG4,IGKC,IGLC2,MALAT1,RPL36,TMSB10.
# m2: 12 markers: ARPP21,CRIP1,IGFBP5,KRT18,KRT8,MUC1,RPL13,RPL41,RPLP1,S100A11,SPAG6,Z82214.2.
# m0: 17 markers: COX6C,CPB1,IFI27,KRT19,LINC00645,MGP,MT-ATP6,MT-CO1,MT-CO2,MT-CO3,MT-CYB,MT-ND1,MT-ND2,MT-ND3,MT-ND4,S100A6,TFF3.
#   0%|          | 0/100 [00:00<?, ?/s]
# Calculating local spatial correlation value...
# Local L elapsed time: 0.172s
# Calculating local spatial correlation value...
# Local L elapsed time: 0.163s
# Calculating local spatial correlation value...
# Local L elapsed time: 0.164s

# %%
seagal.save_modules(sg, 'results/gene_modules.csv')
