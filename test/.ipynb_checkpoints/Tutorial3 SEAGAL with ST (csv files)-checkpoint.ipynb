# %%
from seagal import seagal

# %%
sg = seagal.SEAGAL(count_path='data/Melanoma_CSV/count.csv', meta_path='data/Melanoma_CSV/meta.csv')
# Out:
#   0%|          | 0/1 [00:00<?, ?/s]

# %%
seagal.group_adata_by_genes(sg, inplace=True)
# Out:
# B cells: 13 markers: EBF1,BANK1,CD79A,PAX5,FCHSD2,CD79B,RALGPS2,MS4A1,MEF2C,BACH2,CD55,BTLA,AFF3.
# DC: 16 markers: CRIP1,CST3,CBFA2T3,TCF4,VIM,IRF8,TAGLN2,AHNAK,S100A4,IFI30,LGALS1,CCND1,SYNGR2,H2AFY,BST2,CCDC88A.
# Macrophages: 18 markers: APOE,C1QB,C1QC,C1QA,CCL4,RGS1,CD81,MS4A7,CTSB,LGMN,CTSS,CD63,CD72,CCL3,CTSC,TMEM176B,ACP5,AIF1.
# Monocytes: 13 markers: PLAC8,SLC8A1,FN1,S100A4,F13A1,IFITM3,CCR2,CYBB,CRIP1,LDLRAD3,LRP1,ZEB2,AHNAK.
# Neutrophils: 10 markers: S100A8,S100A9,IFITM1,MMP9,PBX1,MXD1,GSR,S100A11,GCNT2,MSRB1.
# NK cells: 12 markers: GZMA,GZMB,CD7,CCL5,NKG7,IL2RB,KLRD1,PRF1,ARSB,LGALS1,ID2,CST7.
# T cells: 15 markers: LEF1,SKAP1,IL7R,ITK,BCL11B,CD247,TCF7,CD3E,CD3D,INPP4B,CD3G,GRAP2,CAMK4,SATB1,SIDT1.
#   0%|          | 0/100 [00:00<?, ?/s]
# Calculating global graph-based correlation value...

# %%
seagal.spatial_association(sg, grouped_only=True, n_permutation=999)
# Out:
# Calculating global graph-based correlation value...

# %%
seagal.clustermap(sg, figsize=(6,6), use_grouped=True)
## Save the spatial correlation matrix for grouped genes
#  seagal.save_coexpr(sg, path='results/spatial_ct_colocolize.csv', use_grouped=True)

# %%
f,_ = seagal.hotspot(sg, 'B cells', 'T cells', use_grouped=True, cmap='Reds')
# Out:
# Calculating local spatial correlation value...
# Local L elapsed time: 0.005s

# %%
f,_ = seagal.hotspot(sg, 'DC', 'B cells', use_grouped=True, cmap='Blues_r')
# Out:
# Calculating local spatial correlation value...
# Local L elapsed time: 0.005s

# %%
seagal.spatial_pattern_genes(sg, I=0.3)
seagal.spatial_association(sg, grouped_only=False, permute_ratio=0.1)
# Out:
# #Extracted genes with spatial patterns = 69
# #Genes to be used is 69. #Pairs = 2346, Estimated elapsed time: 0.069 hours.
# Calculating global graph-based correlation value...

# %%
f = seagal.volcano(sg, use_grouped=False)

# %%
g = seagal.clustermap(sg, use_grouped=False, figsize=(6, 6))

# %%
seagal.genemodules(sg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.818374643874232
# For n_clusters = 3 The average silhouette_score is : 0.7081235352300906
# For n_clusters = 4 The average silhouette_score is : 0.7029282169051372
# For n_clusters = 5 The average silhouette_score is : 0.14251397859659232
# For n_clusters = 6 The average silhouette_score is : 0.1459159195538126
# Number of selected clusters =  2

# %%
seagal.module_pattern(sg)
# Out:
# m0: 14 markers: ACTB,BANK1,CD37,CD52,CD74,CH507-513H4.5,COL1A1,FAM107B,IGJ,IGLL5,LINC00926,MS4A1,MYL9,RPLP1.
# m1: 55 markers: ALDH1A3,ANXA5,CD320,COL14A1,CPEB2,CSPG4,CTSK,CYTH3,DLL3,DUSP4,EPHA2,F2R,FGL2,FKBP10,GAPDH,GDF15,GNG12,GPNMB,HAPLN1,HIPK2,HMCN1,HMGA2,HPGD,HSPA2,IVNS1ABP,KDR,MCAM,METTL9,MLANA,MOK,MT2A,NDRG1,PCNA,PEG10,PHLDA1,PLA1A,PMEL,PRAME,RAB38,RAD21,RIPK4,S100B,SEC11C,SEMA3C,SFRP1,SLC35B2,SLC6A8,SLC7A8,SOX10,SPP1,STK32A,TBC1D4,TYR,XAGE1A,XAGE1B.
#   0%|          | 0/100 [00:00<?, ?/s]

# %%
seagal.module_hotspot(sg)
# Out:
# m0: 14 markers: ACTB,BANK1,CD37,CD52,CD74,CH507-513H4.5,COL1A1,FAM107B,IGJ,IGLL5,LINC00926,MS4A1,MYL9,RPLP1.
# m1: 55 markers: ALDH1A3,ANXA5,CD320,COL14A1,CPEB2,CSPG4,CTSK,CYTH3,DLL3,DUSP4,EPHA2,F2R,FGL2,FKBP10,GAPDH,GDF15,GNG12,GPNMB,HAPLN1,HIPK2,HMCN1,HMGA2,HPGD,HSPA2,IVNS1ABP,KDR,MCAM,METTL9,MLANA,MOK,MT2A,NDRG1,PCNA,PEG10,PHLDA1,PLA1A,PMEL,PRAME,RAB38,RAD21,RIPK4,S100B,SEC11C,SEMA3C,SFRP1,SLC35B2,SLC6A8,SLC7A8,SOX10,SPP1,STK32A,TBC1D4,TYR,XAGE1A,XAGE1B.
#   0%|          | 0/100 [00:00<?, ?/s]
# Calculating local spatial correlation value...
# Local L elapsed time: 0.005s
