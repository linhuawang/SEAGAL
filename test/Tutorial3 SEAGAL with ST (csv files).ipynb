# %%
from seagal import seagal

# %%
sg = seagal.SEAGAL(count_path='data/Melanoma_CSV/count.csv', meta_path='data/Melanoma_CSV/meta.csv')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#   0%|          | 0/1 [00:00<?, ?/s]

# %%
seagal.group_adata_by_genes(sg, inplace=True, reference='hpca')
# Out:
# B cells: 14 markers: POU2AF1,MS4A1,VPREB3,TCL1A,STAP1,BLNK,CD19,CR2,CD79A,HLA-DOB,FCRLA,P2RX5,CD79B,RGS13.
# Endothelial cells: 15 markers: GJA1,CTGF,EFEMP1,PLS3,CAV1,CDH5,ARHGAP29,FSTL1,SRPX,CYR61,CAV2,LAMB1,TM4SF1,MMRN1,GNG11.
# Macrophages: 17 markers: GPNMB,MRC1,CHI3L1,SPP1,APOC1,LPL,APOE,ADAMDEC1,CCL18,C1QA,C15ORF48,C1QC,C1QB,NR1H3,CYP1B1,MMP9,A2M.
# Monocytes: 16 markers: FCN1,VCAN,S100A8,CSTA,LYZ,MPEG1,CD14,S100A9,LILRB2,TYROBP,MNDA,CPVL,HCK,CFP,NCF2,FCER1G.
# Neutrophils: 2 markers: G0S2,CXCL1.
# T cells: 15 markers: ITK,CD3D,CD3G,CD2,LCK,NELL2,NLRC3,CD69,KLRB1,RASGRP1,BCL11B,GZMK,GZMA,TC2N,ITM2A.
#   0%|          | 0/100 [00:00<?, ?/s]
# Calculating global graph-based correlation value...

# %%
seagal.spatial_association(sg, grouped_only=True, n_permutation=999)
# Out:
# Calculating global graph-based correlation value...

# %%
seagal.clustermap(sg, figsize=(6,6), use_grouped=True)
## Save the spatial correlation matrix for grouped genes
#  seagal.save_coexpr(sg, path='results/spatial_ct_colocolize.csv', use_grouped=True)

# %%
f,_ = seagal.hotspot(sg, 'B cells', 'T cells', use_grouped=True, cmap='Reds')
# Out:
# Calculating local spatial correlation value...
# Local L elapsed time: 0.008s

# %%
f,_ = seagal.hotspot(sg, 'Macrophages', 'B cells', use_grouped=True, cmap='Blues_r')
# Out:
# Calculating local spatial correlation value...
# Local L elapsed time: 0.010s

# %%
seagal.spatial_pattern_genes(sg, I=0.3)
seagal.spatial_association(sg, grouped_only=False, permute_ratio=0.1)
# Out:
# #Extracted genes with spatial patterns = 71
# #Genes to be used is 71. #Pairs = 2485, Estimated elapsed time: 0.071 hours.
# Calculating global graph-based correlation value...

# %%
f = seagal.volcano(sg, use_grouped=False)

# %%
g = seagal.clustermap(sg, use_grouped=False, figsize=(6, 6))

# %%
seagal.genemodules(sg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.8039899184825535
# For n_clusters = 3 The average silhouette_score is : 0.6916161471773176
# For n_clusters = 4 The average silhouette_score is : 0.667797088877933
# For n_clusters = 5 The average silhouette_score is : 0.14604882552346968
# For n_clusters = 6 The average silhouette_score is : 0.14627386743503729
# Number of selected clusters =  2

# %%
seagal.module_pattern(sg)
# Out:
# m0: 14 markers: ACTB,BANK1,CD37,CD52,CD74,CH507-513H4.5,COL1A1,CTSS,FAM107B,IGJ,IGLL5,MS4A1,MYL9,RPLP1.
# m1: 57 markers: ALDH1A3,ANXA5,CD320,COL14A1,CPEB2,CSPG4,CTSK,CYTH3,DLL3,DUSP4,EPHA2,EVA1A,F2R,FGL2,FKBP10,GAPDH,GDF15,GNG12,GPNMB,HAPLN1,HIPK2,HMCN1,HMGA2,HPGD,HSPA2,IVNS1ABP,KDR,MCAM,METTL9,MLANA,MOK,MT2A,NDRG1,PCNA,PHLDA1,PLA1A,PMEL,PRAME,RAB38,RAD21,RIPK4,S100B,SEC11C,SEMA3C,SFRP1,SLC35B2,SLC6A8,SLC7A8,SOX10,SPP1,STK32A,TBC1D4,TSPAN7,TYR,WARS,XAGE1A,XAGE1B.
#   0%|          | 0/100 [00:00<?, ?/s]

# %%
seagal.module_hotspot(sg)
# Out:
# m0: 14 markers: ACTB,BANK1,CD37,CD52,CD74,CH507-513H4.5,COL1A1,CTSS,FAM107B,IGJ,IGLL5,MS4A1,MYL9,RPLP1.
# m1: 57 markers: ALDH1A3,ANXA5,CD320,COL14A1,CPEB2,CSPG4,CTSK,CYTH3,DLL3,DUSP4,EPHA2,EVA1A,F2R,FGL2,FKBP10,GAPDH,GDF15,GNG12,GPNMB,HAPLN1,HIPK2,HMCN1,HMGA2,HPGD,HSPA2,IVNS1ABP,KDR,MCAM,METTL9,MLANA,MOK,MT2A,NDRG1,PCNA,PHLDA1,PLA1A,PMEL,PRAME,RAB38,RAD21,RIPK4,S100B,SEC11C,SEMA3C,SFRP1,SLC35B2,SLC6A8,SLC7A8,SOX10,SPP1,STK32A,TBC1D4,TSPAN7,TYR,WARS,XAGE1A,XAGE1B.
#   0%|          | 0/100 [00:00<?, ?/s]
# Calculating local spatial correlation value...
# Local L elapsed time: 0.006s
